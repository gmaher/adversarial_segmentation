# %%
from keras.models import load_model
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/marsdenlab/libraries/keras-fcn')
sys.path.append('/home/marsdenlab/libraries/keras-fcn/voc2011/')
import yaml
with open("init_args.yml", 'r') as stream:
    try:
        init_args = yaml.load(stream)
    except yaml.YAMLError as exc:
        print(exc)
# Out:
# Using TensorFlow backend.

# %%
fcn = load_model('./output/fcn_vgg16.h5')

# %%
fcn.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 500, 500, 3)   0
# ____________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D) (None, 700, 700, 3)   0
# ____________________________________________________________________________________________________
# conv1_1 (Conv2D)                 (None, 698, 698, 64)  1792
# ____________________________________________________________________________________________________
# conv1_2 (Conv2D)                 (None, 698, 698, 64)  36928
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)             (None, 349, 349, 64)  0
# ____________________________________________________________________________________________________
# conv2_1 (Conv2D)                 (None, 349, 349, 128) 73856
# ____________________________________________________________________________________________________
# conv2_2 (Conv2D)                 (None, 349, 349, 128) 147584
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)             (None, 175, 175, 128) 0
# ____________________________________________________________________________________________________
# conv3_1 (Conv2D)                 (None, 175, 175, 256) 295168
# ____________________________________________________________________________________________________
# conv3_2 (Conv2D)                 (None, 175, 175, 256) 590080
# ____________________________________________________________________________________________________
# conv3_3 (Conv2D)                 (None, 175, 175, 256) 590080
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)             (None, 88, 88, 256)   0
# ____________________________________________________________________________________________________
# conv4_1 (Conv2D)                 (None, 88, 88, 512)   1180160
# ____________________________________________________________________________________________________
# conv4_2 (Conv2D)                 (None, 88, 88, 512)   2359808
# ____________________________________________________________________________________________________
# conv4_3 (Conv2D)                 (None, 88, 88, 512)   2359808
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)             (None, 44, 44, 512)   0
# ____________________________________________________________________________________________________
# conv5_1 (Conv2D)                 (None, 44, 44, 512)   2359808
# ____________________________________________________________________________________________________
# conv5_2 (Conv2D)                 (None, 44, 44, 512)   2359808
# ____________________________________________________________________________________________________
# conv5_3 (Conv2D)                 (None, 44, 44, 512)   2359808
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)             (None, 22, 22, 512)   0
# ____________________________________________________________________________________________________
# fc6 (Conv2D)                     (None, 16, 16, 4096)  102764544
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 16, 16, 4096)  0
# ____________________________________________________________________________________________________
# fc7 (Conv2D)                     (None, 16, 16, 4096)  16781312
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 16, 16, 4096)  0
# ____________________________________________________________________________________________________
# scale_pool4 (Lambda)             (None, 44, 44, 512)   0
# ____________________________________________________________________________________________________
# score_fr (Conv2D)                (None, 16, 16, 21)    86037
# ____________________________________________________________________________________________________
# score_pool4 (Conv2D)             (None, 44, 44, 21)    10773
# ____________________________________________________________________________________________________
# upscore2 (Conv2DTranspose)       (None, 34, 34, 21)    7056
# ____________________________________________________________________________________________________
# score_pool4c (Cropping2D)        (None, 34, 34, 21)    0
# ____________________________________________________________________________________________________
# scale_pool3 (Lambda)             (None, 88, 88, 256)   0
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 34, 34, 21)    0
# ____________________________________________________________________________________________________
# score_pool3 (Conv2D)             (None, 88, 88, 21)    5397
# ____________________________________________________________________________________________________
# upscore_pool4 (Conv2DTranspose)  (None, 70, 70, 21)    7056
# ____________________________________________________________________________________________________
# score_pool3c (Cropping2D)        (None, 70, 70, 21)    0
# ____________________________________________________________________________________________________
# add_2 (Add)                      (None, 70, 70, 21)    0
# ____________________________________________________________________________________________________
# upscore8 (Conv2DTranspose)       (None, 568, 568, 21)  112896
# ____________________________________________________________________________________________________
# score (Cropping2D)               (None, 500, 500, 21)  0
# ====================================================================================================
# Total params: 134,489,759
# Trainable params: 134,489,759
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#Get VOC data
from voc_generator import PascalVocGenerator, ImageSetLoader
datagen = PascalVocGenerator(**init_args['pascal_voc_generator']['train'])
val_loader = ImageSetLoader(**init_args['image_set_loader']['val'])

flow_args = init_args['pascal_voc_generator']['flow_from_imageset']
val_flow_args = flow_args.copy()
val_flow_args['image_set_loader'] = val_loader

iterator = datagen.flow_from_imageset(**val_flow_args)

# %%
X = []
Y = []
for i in range(200):
    x,y = iterator.next()
    X.append(x)
    Y.append(y)
    
X=np.array(X)[:,0,:,:,:]
Y=np.array(Y)[:,0,:,:,:]
Xnorm = X/np.std(X)
print X.shape, Y.shape, Xnorm.shape
# Out:
#  (200, 500, 500, 3) (200, 500, 500, 21) (200, 500, 500, 3)

# %%
loss = fcn.evaluate(X,Y, batch_size=1)
# Out:
# 200/200 [==============================] - 23s

# %%
yhat = fcn.predict(Xnorm, batch_size=1)

# %%
# %matplotlib inline
print loss
print np.mean(X[0])
print yhat[0,250,250]

plt.figure()
plt.imshow(Xnorm[0])
plt.colorbar()
plt.show()
# Out:
# [1.1920931797249068e-07, 0.73864687325898559, 0.73864687325898559]
# -27.6479
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan]

# %%
import keras.backend as k

# %%
layer_dict = dict([(layer.name, layer) for layer in fcn.layers])
print layer_dict['input_1']
print layer_dict['score']
# Out:
# <keras.engine.topology.InputLayer object at 0x7fd680d6b590>
# <keras.layers.convolutional.Cropping2D object at 0x7fd68099f890>
